# %% [markdown]
# # Amazon Sales  Analysis

# %% [markdown]
# # INDRODUCTION

# %% [markdown]
# This dataset consists more than 1000 of real products with their identification number listed in the Amazon marketplace specifically from the region India. I noticed the region due to the currency used in the dataset is Rupee India. My objective is to clean and prepare the data due to the raw data being very unorganized. I will then move on to finding insights about the data and try to elaborate in the form of visualization.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Read the file 
df=pd.read_csv("C:\\Users\\LENOVO\\Videos\\amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
#Checking the columns 
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
#checking the datatype 
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
# Changing the data types 
df['discounted_price']=df['discounted_price'].str.replace("₹",'')
df['discounted_price']=df['discounted_price'].str.replace(",",'')
df['discounted_price']=df['discounted_price'].astype('float64')

df['actual_price']=df['actual_price'].str.replace("₹",'')
df['actual_price']=df['actual_price'].str.replace(",",'')
df['actual_price']=df['actual_price'].astype('float64')

# %%
df['discounted_percentage']=df['discount_percentage'].str.replace("%",'').astype('float64')/100
df['discounted_percentage']
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discounted_percentage, Length: 1465, dtype: float64

# %%
df['rating_count'] = (df['rating_count'].astype(str).str.replace(',', '', regex=False).astype(float))

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage rating  rating_count  \
# 0        1099.0                 64%    4.2       24269.0
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 3.0      3
# 4.8      3
# 5.0      3
# 2.8      2
# 3.2      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
# Checking that row 
df.query('rating=="|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price discount_percentage rating  rating_count  \
# 1279        2499.0                 16%      |         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %% [markdown]
# i went to the amazon website and found the similar product id with the same product having
# the rating of 4 . so i am going to give the item rating of 4.0 Providing the website
# link:https://www.amazon.in/Eureka-Forbes-Vacuum-Cleaner-Washable/dp/B08L12N5H1

# %%
#Replacing the value and changing the dataype
df['rating']=df['rating'].replace("|",'4.0').astype('float64')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage  rating  rating_count  \
# 0        1099.0                 64%     4.2       24269.0
# ...

# %%
#Checking the duplicate Values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There is No Duplicate

# %%
#Checking the Missing Values 
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# category                 0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             2
# about_product            0
# user_id                  0
# user_name                0
# review_id                0
# review_title             0
# review_content           0
# img_link                 0
# product_link             0
# discounted_percentage    0
# dtype: int64

# %%
# Treating the missing value 
df['rating_count'].fillna(df['rating_count'].mode()[0],inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\1129659448.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating_count'].fillna(df['rating_count'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# product_id               0
# product_name             0
# category                 0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   0
# rating_count             0
# about_product            0
# user_id                  0
# user_name                0
# review_id                0
# review_title             0
# review_content           0
# img_link                 0
# product_link             0
# discounted_percentage    0
# dtype: int64

# %%
# Creating a new dataframe for category 
df1=df[['product_id','product_name','category','discounted_price','actual_price','discounted_percentage','rating','rating_count']]

# %%
#Splitting the string
catsplit=df['category'].str.split("|",expand=True)

# %%
catsplit
# Out:
#                           0                           1  \
# 0     Computers&Accessories     Accessories&Peripherals
# 1     Computers&Accessories     Accessories&Peripherals
# 2     Computers&Accessories     Accessories&Peripherals
# 3     Computers&Accessories     Accessories&Peripherals
# 4     Computers&Accessories     Accessories&Peripherals
# ...                     ...                         ...
# 1460           Home&Kitchen      Kitchen&HomeAppliances
# 1461           Home&Kitchen      Kitchen&HomeAppliances
# 1462           Home&Kitchen  Heating,Cooling&AirQuality
# 1463           Home&Kitchen  Heating,Cooling&AirQuality
# 1464           Home&Kitchen      Kitchen&HomeAppliances
#
#                                2                         3          4     5  \
# 0             Cables&Accessories                    Cables  USBCables  None
# 1             Cables&Accessories                    Cables  USBCables  None
# ...

# %%
# remaining the column 
catsplit=catsplit.rename(columns={0:'Category_1',1:'Category_2',2:'Category_3'})

# %%
#Adding column into dataframe 
df1['Category_1']=catsplit['Category_1']
df1['Category_2']=catsplit['Category_2']
df1.drop(columns='category',inplace=True)
df1
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\198296408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_1']=catsplit['Category_1']
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\198296408.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_2']=catsplit['Category_2']
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\198296408.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#Counting the Category Column
df1['Category_1'].value_counts()
# Out:
# Category_1
# Electronics              526
# Computers&Accessories    453
# Home&Kitchen             448
# OfficeProducts            31
# MusicalInstruments         2
# HomeImprovement            2
# Toys&Games                 1
# Car&Motorbike              1
# Health&PersonalCare        1
# Name: count, dtype: int64

# %%
# Arranging the string in category_1 
df1['Category_1']=df1['Category_1'].str.replace('&',' & ')
df1['Category_1']=df1['Category_1'].str.replace('OfficeProducts','Office Products')
df1['Category_1']=df1['Category_1'].str.replace('MuscialInstruments','Muscial Instruments')
df1['Category_1']=df1['Category_1'].str.replace('HomeImprovement','Home Improvement')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\565475395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_1']=df1['Category_1'].str.replace('&',' & ')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\565475395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_1']=df1['Category_1'].str.replace('OfficeProducts','Office Products')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\565475395.py:4: SettingWithCopyWarning:
# ...

# %%
#Counting the Category 2 Column
df1['Category_2'].value_counts()
# Out:
# Category_2
# Accessories&Peripherals                    381
# Kitchen&HomeAppliances                     308
# HomeTheater,TV&Video                       162
# Mobiles&Accessories                        161
# Heating,Cooling&AirQuality                 116
# WearableTechnology                          76
# Headphones,Earbuds&Accessories              66
# NetworkingDevices                           34
# OfficePaperProducts                         27
# ExternalDevices&DataStorage                 18
# Cameras&Photography                         16
# HomeStorage&Organization                    16
# HomeAudio                                   16
# GeneralPurposeBatteries&BatteryChargers     14
# Accessories                                 14
# Printers,Inks&Accessories                   11
# CraftMaterials                               7
# Components                                   5
# OfficeElectronics                            4
# Microphones                                  2
# ...

# %%
#Replacing the Strings 
df1['Category_1']=df1['Category_1'].str.replace('&',' & ')
df1['Category_1']=df1['Category_1'].str.replace(',',', ')
df1['Category_1']=df1['Category_1'].str.replace('HomeAppliances','Home Appliances')
df1['Category_1']=df1['Category_1'].str.replace('HomeTheater','Home Theater')
df1['Category_1']=df1['Category_1'].str.replace('WearableTechnology','Wearable Technology')
df1['Category_1']=df1['Category_1'].str.replace('NetworkingDevices','Networking Devices')
df1['Category_1']=df1['Category_1'].str.replace('OfficePaperProducts','Office Paper Products')
df1['Category_1']=df1['Category_1'].str.replace('ExternalDevices','External Devices')
df1['Category_1']=df1['Category_1'].str.replace('DataStorage','Data Storage')
df1['Category_1']=df1['Category_1'].str.replace('HomeStorage','Home Storage')
df1['Category_1']=df1['Category_1'].str.replace('HomeAudio ','Home Audio')
df1['Category_1']=df1['Category_1'].str.replace('GeneralPurposeBatteries','General Purpose Batteries')
df1['Category_1']=df1['Category_1'].str.replace('BatteryChargers','Battery Chargers')
df1['Category_1']=df1['Category_1'].str.replace('CraftMaterials','Craft Materials')
df1['Category_1']=df1['Category_1'].str.replace('OfficeElectronics','Office Electronics')
df1['Category_1']=df1['Category_1'].str.replace('PowerAccessories','Power Accessories')
df1['Category_1']=df1['Category_1'].str.replace('CarAccessories','Car Accessories')
df1['Category_1']=df1['Category_1'].str.replace('HomeMedicalSupplies','Home Medical Supplies')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3582805486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_1']=df1['Category_1'].str.replace('&',' & ')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3582805486.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Category_1']=df1['Category_1'].str.replace(',',', ')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3582805486.py:4: SettingWithCopyWarning:
# ...

# %%
# Removing the wide space of product Id
df1['product_id'].str.strip()
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1465, dtype: object

# %%
# Creating Category for raking 
rating_score=[]
for score in df1['rating']:
    if score <2.0 : rating_score.append('Poor')
    elif score < 3.0 : rating_score.append('Below Average')
    elif score < 4.0 : rating_score.append('Average')
    elif score < 5.0 : rating_score.append('Above Average')
    elif score ==5.0 : rating_score.append('Excellent')

# %% [markdown]
# Created a a Rating Category that consists of:
# 1. Score below 2.0 = Poor
# 2. Score range of 2.0 - 2.9 = Below Average
# 3. Score range of 3.0 - 3.9 = Average
# 4. Score Range of 4.0 - 4.9 = Above Average
# 5. Score of 5.0 = Excellent

# %%
#Creating the new column changing the datatype
df1['rating_score'] =rating_score
df1['rating_score'] =df1['rating_score'].astype('category')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3806723689.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rating_score'] =rating_score
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3806723689.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rating_score'] =df1['rating_score'].astype('category')

# %%
# reordering the Category
df1['rating_score']=df1['rating_score'].cat.reorder_categories(['Below Average','Average','Above Average',
                                                                'Excellent'],ordered=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\782236395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['rating_score']=df1['rating_score'].cat.reorder_categories(['Below Average','Average','Above Average',

# %%
# Creating Difference of Price Column 
df1['difference_price']=df1['actual_price']-df1['discounted_price']
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\2370283911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['difference_price']=df1['actual_price']-df1['discounted_price']

# %%
#Result after cleaning 
df1.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discounted_percentage  rating  \
# 0             399.0        1099.0                   0.64     4.2
# 1             199.0         349.0                   0.43     4.0
# 2             199.0        1899.0                   0.90     3.9
# 3             329.0         699.0                   0.53     4.2
# 4             154.0         399.0                   0.61     4.2
#
#    rating_count                 Category_1               Category_2  \
# 0       24269.0  Computers  &  Accessories  Accessories&Peripherals
# ...

# %%
# Setting the review Identification
reviewers=df[['user_id','user_name']]
reviewers
# Out:
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# ...

# %%
#Splitting the user id 
Splitting_user_id=reviewers['user_id'].str.split(',',expand=False)
Splitting_user_id
# Out:
# 0       [AG3D6O4STAQKAY2UVGEUV46KN35Q, AHMY5CWJMMK5BJR...
# 1       [AECPFYFQVRUWC3KGNLJIOREFP5LQ, AGYYVPDD7YG7FYN...
# 2       [AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA, AESFLDV2PT363T2...
# 3       [AEWAZDZZJLQUYVOVGBEUKSLXHQ5A, AG5HTSFRRE6NL3M...
# 4       [AE3Q6KSUK5P75D5HFYHCRAOLODSA, AFUGIFH5ZAFXRDS...
#                               ...
# 1460    [AHITFY6AHALOFOHOZEOC6XBP4FEA, AFRABBODZJZQB6Z...
# 1461    [AFG5FM3NEMOL6BNFRV2NK5FNJCHQ, AGEINTRN6Z563RM...
# 1462    [AGVPWCMAHYQWJOQKMUJN4DW3KM5Q, AF4Q3E66MY4SR7Y...
# 1463    [AF2JQCLSCY3QJATWUNNHUSVUPNQQ, AFDMLUXC5LS5RXD...
# 1464    [AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA, AG7QNJ2SCS5VS5V...
# Name: user_id, Length: 1465, dtype: object

# %%
#Making user_id Display 1 per Row
reviewer_exp_id=Splitting_user_id.explode()
reviewer_clean_id=reviewer_exp_id.reset_index(drop=True)
reviewer_clean_id
# Out:
# 0        AG3D6O4STAQKAY2UVGEUV46KN35Q
# 1        AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 2        AHCTC6ULH4XB6YHDY6PCH2R772LQ
# 3        AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 4        AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q
#                      ...
# 11498    AHXCDNSXAESERITAFELQABFVNLCA
# 11499    AGRZD6CHLCUNOLMMIMIHUCG7PIFA
# 11500    AFQZVGSOSOJHKFQQMCEI4725QEKQ
# 11501    AEALVGXXIP46OZVXKRUXSDWZJMEA
# 11502    AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ
# Name: user_id, Length: 11503, dtype: object

# %%
#Splitting the user name
Splitting_user_name=reviewers['user_name'].str.split(',',expand=False)
Splitting_user_name
# Out:
# 0       [Manav, Adarsh gupta, Sundeep, S.Sayeed Ahmed,...
# 1       [ArdKn, Nirbhay kumar, Sagar Viswanathan, Asp,...
# 2       [Kunal, Himanshu, viswanath, sai niharka, saqi...
# 3       [Omkar dhale, JD, HEMALATHA, Ajwadh a., amar s...
# 4       [rahuls6099, Swasat Borah, Ajay Wadke, Pranali...
#                               ...
# 1460    [Prabha ds, Raghuram bk, Real Deal, Amazon Cus...
# 1461    [Manu Bhai, Naveenpittu, Evatira Sangma, JAGAN...
# 1462    [Nehal Desai, Danish Parwez, Amazon Customer, ...
# 1463    [Shubham Dubey, E.GURUBARAN, Mayank S., eusuf ...
# 1464    [Rajib, Ajay B, Vikas Kahol, PARDEEP, Anindya ...
# Name: user_name, Length: 1465, dtype: object

# %%
#Making user_id Display 1 per Row
reviewer_exp_name=Splitting_user_name.explode()
reviewer_clean_name=reviewer_exp_name.reset_index(drop=True)
reviewer_clean_name
# Out:
# 0                   Manav
# 1            Adarsh gupta
# 2                 Sundeep
# 3          S.Sayeed Ahmed
# 4          jaspreet singh
#                ...
# 11510             PARDEEP
# 11511    Anindya Pramanik
# 11512         Vikas Singh
# 11513     Harshada Pimple
# 11514              Saw a.
# Name: user_name, Length: 11515, dtype: object

# %%
#Converting dataframe to merge 
df21=pd.DataFrame(data=reviewer_clean_id)
df22=pd.DataFrame(data=reviewer_clean_name)

# %%
#Merging the dataframe
df2=pd.merge(df21,df22,left_index=True,right_index=True)

# %%
df2.head()
# Out:
#                         user_id       user_name
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh

# %%
df3=pd.merge(df2,df1,left_index=True,right_index=True)

# %%
df3.head(5)
# Out:
#                         user_id       user_name  product_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav  B07JW9H4J1
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta  B098NS6PVG
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep  B096MSW6CT
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed  B08HDJ86NZ
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh  B08CF3B7N1
#
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discounted_percentage  rating  rating_count  \
# 0        1099.0                   0.64     4.2       24269.0
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# In this stage I will try to elaborate my insights through Visualizations, Pivot Tables, and short
# explanations

# %%
sns.set_style(style='whitegrid')
sns.set_palette(palette='Set2')

# %%
# Lets Check by the table Category and Sub-Category 
main_sub=df1[['Category_1','Category_2','product_id']]
main_sub=main_sub.rename(columns={'Category_1':'Category','Category_2':'Sub-Category','product_id':'Producd ID'})
main_sub_piv=pd.pivot_table(main_sub, index=['Category', 'Sub-Category'], aggfunc='count')
main_sub_piv
# Out:
#                                                                    Producd ID
# Category                  Sub-Category
# Car  &  Motorbike         CarAccessories                                    1
# Computers  &  Accessories Accessories&Peripherals                         381
#                           Components                                        5
#                           ExternalDevices&DataStorage                      18
#                           Laptops                                           1
#                           Monitors                                          2
#                           NetworkingDevices                                34
#                           Printers,Inks&Accessories                        11
#                           Tablets                                           1
# Electronics               Accessories                                      14
# ...

# %% [markdown]
# # Observation First : Product Category

# %%
#Product by Category
most_main_items = (df1['Category_1'].value_counts().head(5).rename_axis('Category_1').reset_index(name='counts'))
plt.figure(figsize=(8, 6))
ax = sns.barplot(data=most_main_items,x='counts',y='Category_1',palette="Blues")
ax.set_xlabel('Count', fontweight='bold')
ax.set_ylabel('Product Category', fontweight='bold')
ax.set_title('Top 5 Product Category', fontweight='bold')
ax.bar_label(ax.containers[0])
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\2207756624.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=most_main_items,x='counts',y='Category_1',palette="Blues")

# %% [markdown]
# We can see that Most of the Product Category is from Electronics ,Computers & Accessoris  then Home & Kitchen .

# %%
# Product by Subcategory 
most_sub_items = (df1['Category_2'].value_counts().head(10).rename_axis('Category_2').reset_index(name='counts'))
plt.figure(figsize=(8, 6))
ax = sns.barplot(data=most_sub_items,x='counts',y='Category_2',palette="Blues")
ax.set_xlabel('Count', fontweight='bold')
ax.set_ylabel('Product Sub-Category', fontweight='bold')
ax.set_title('Top 10 Product Sub-Category', fontweight='bold')
ax.bar_label(ax.containers[0], padding=3)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\1604938821.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=most_sub_items,x='counts',y='Category_2',palette="Blues")

# %% [markdown]
# Most of the Sub-Categories  from Accessories and Peripherals ,Kitchen and Home Appliances,HomeTheather and TV Video this all sub-Category mostly belongs to Electronics Category.

# %%
# top 5 Most Expensive Product after Discount 
Dis_price=sns.barplot(data=df1.sort_values('discounted_price',ascending=False).head(5),x='discounted_price',y='product_name',palette="Blues")
Dis_price.set_xlabel('Discounted Price(Indian Rupee)', fontweight='bold')
Dis_price.set_ylabel('Product Name', fontweight='bold')
Dis_price.set_title('Top 5 Expensive Product After Discount', fontweight='bold')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\740518663.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   Dis_price=sns.barplot(data=df1.sort_values('discounted_price',ascending=False).head(5),x='discounted_price',y='product_name',palette="Blues")
# Text(0.5, 1.0, 'Top 5 Expensive Product After Discount')

# %% [markdown]
#  Sony Bravia 164 cm  4k Ultra HD Smart LED TV (Black) most expensive product after discount which is from the Category of electronics.

# %%
#Top 5 Cheapest Product after discount
Dis_cheap=sns.barplot(data=df1.sort_values('discounted_price').head(5),x='discounted_price',y='product_name',palette="Blues")
Dis_cheap.set_xlabel('Discounted Price', fontweight='bold')
Dis_cheap.set_ylabel('Product Name', fontweight='bold')
Dis_cheap.set_title('Top 5 Cheapest Product After Discount', fontweight='bold')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\4229757097.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   Dis_cheap=sns.barplot(data=df1.sort_values('discounted_price').head(5),x='discounted_price',y='product_name',palette="Blues")
# Text(0.5, 1.0, 'Top 5 Cheapest Product After Discount')

# %% [markdown]
# Inventis 5V 1.2W Portable Flexible USB LED light Lamp  is the cheapest product after discount

# %%
#Top 5 Largest Price difference due to the dicount in the product 
diff_price=sns.barplot(data=df1.sort_values('difference_price',ascending=False).head(5),x='difference_price',y='product_name',palette="Blues")
diff_price.set_xlabel('Price Difference', fontweight='bold')
diff_price.set_ylabel('Product Name', fontweight='bold')
diff_price.set_title('Top 5 Largest Price Difference Due to discount', fontweight='bold')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\1482769239.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   diff_price=sns.barplot(data=df1.sort_values('difference_price',ascending=False).head(5),x='difference_price',y='product_name',palette="Blues")
# Text(0.5, 1.0, 'Top 5 Largest Price Difference Due to discount')

# %% [markdown]
# Sony Bravia 164 cm 4k Ultra HD Smart is the product which is creating the largest price difference due to discount

# %% [markdown]
# # Observation 2 : Correlation Between the Features

# %%
# Correlation Between Actual Price and discounted price 
plt.figure()
plt.scatter(df1["actual_price"], df1["discounted_price"])
plt.xlabel("Actual Price")
plt.ylabel("Discounted Price")
plt.title("Actual vs Discounted Price")
plt.show()

# %% [markdown]
# Their is a strong linear relationship the high ticket items greater than 50k still recieve heavy discount.

# %% [markdown]
# We  are Scarifing the large amount of profit by significant margin scarifice even on premium product.

# %% [markdown]
# # Observation 3 : Product Rating

# %%
# Product Rating distribution 
plt.figure()
plt.hist(df1["rating"].dropna(), bins=20)
plt.title("Product Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Products")
plt.show()

# %% [markdown]
# Majortity of the product lie between 4.0 to 4.5 and very few product are below 3.5 that indicates strong quality control
# Low rated product are rare but risky .

# %%
# Rating distribution with repect to category 
cat_rating = (df1.groupby(["Category_1", "rating_score"]).size().unstack(fill_value=0))
cat_rating.plot(kind="bar", stacked=True)
plt.title("Rating Score Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Number of Products")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\1921478466.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cat_rating = (df1.groupby(["Category_1", "rating_score"]).size().unstack(fill_value=0))

# %% [markdown]
# The most of the product are above average  specially Computers & Accessories ,Electronics ,Home & kitchen Office Product this are scalable Category

# %%
top_sub = df1["Category_2"].value_counts().head(10).index

sub_rating = (df1[df1["Category_2"].isin(top_sub)].groupby(["Category_2", "rating_score"]).size().unstack(fill_value=0))

sub_rating.plot(kind="bar", stacked=True)
plt.title("Rating Score Distribution by Sub-Category (Top 10)")
plt.xlabel("Sub-Category")
plt.ylabel("Number of Products")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\3306038900.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sub_rating = (df1[df1["Category_2"].isin(top_sub)].groupby(["Category_2", "rating_score"]).size().unstack(fill_value=0))

# %% [markdown]
# I can see that  most of the subcategory is the category of average and above average Scalable subcategory

# %% [markdown]
# # Oservation 3 : Reviewers

# %%
# Reviewers who gave review for more than one product 
top_reviewer=data=df2['user_name'].value_counts().head(10).rename_axis('username').reset_index(name='counts')
top_review_plot=sns.barplot(data=top_reviewer,x='counts',y='username',palette='Blues')
top_review_plot.bar_label(top_review_plot.containers[0])

top_review_plot.set_xlabel('Amount of Rating Reviews Given',fontweight='bold')
top_review_plot.set_ylabel('Reviewers name',fontweight='bold')
top_review_plot.set_title('Top 10 Active Reviewers',fontweight='heavy',size='x-large',y=1.03)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1240\2300191627.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   top_review_plot=sns.barplot(data=top_reviewer,x='counts',y='username',palette='Blues')

# %% [markdown]
# More than 500 active reviewers who review the product under Amazon Customer,Placeholder,Kindle Customers .This are active customers who gave more than 10 reviews in the Category.

# %%
# Reviews vs Rating
plt.figure()
plt.scatter(df1["rating_count"], df["rating"])
plt.xlabel("Number of Reviews")
plt.ylabel("Rating")
plt.title("Reviews vs Rating")
plt.show()

# %% [markdown]
# Product with high rating (100k+) mostly stay around between 4.0 to 4.3
# Rating Stability as review increases .
# Low reviews show high rating volatility.

# %% [markdown]
# # Observation 4 : Product Pricing

# %%
#Discounter Percentage distribution
plt.figure()
plt.hist(df1["discounted_percentage"], bins=20)
plt.title("Discount Percentage Distribution")
plt.xlabel("Discount %")
plt.ylabel("Number of Products")
plt.show()

# %% [markdown]
# Most product fall between 30% to 70% discount
#
# Extreme discount 80% to 90% exist but are fewer.
#
# very low discount  less the 10% is uncommom.

# %%
#Discount vs Rating 
plt.figure()
plt.scatter(df1["discounted_percentage"], df["rating"])
plt.xlabel("Discount %")
plt.ylabel("Rating")
plt.title("Discount vs Rating")
plt.show()

# %% [markdown]
# No Relationship between Higher discount and higher rating.
#
# Product between (10%-20%) disount have the rating of 4.5 rating.
#
# Over discountring does not improve customer satisfaction.

# %%
# saving the dataframe
df3.to_csv(r'C:\\Users\\LENOVO\\Downloads\\Amazon_Clean_dataset2.csv')
